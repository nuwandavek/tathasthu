# %%
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from fuzzysearch import find_near_matches

# %%
train = pd.read_csv('ttrain.csv')
manufacturers = pd.read_csv("manufacturer_list.csv")
print(train.head())
print(manufacturers.head())
# Out:
#                                     article_name  \
# 0                    Chicken Burger Patty (250G)
# 1              BRITANNIA DAILY FAMILY LONG BREAD
# 2  POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                            FEVIBOND TUBE 20 ML
# 4             KITKAT DESSERT DELIGHT TRUFFLE 50g
#
#                             manufacturer_description  Unnamed: 2  Unnamed: 3  \
# 0  Company Name - VENKYS INDIA LTD<br />Membershi...         NaN         NaN
# 1  Company Name - BRITANNIA INDUSTRIES LTD<br />M...         NaN         NaN
# 2  Company Name - FUTURE CONSUMER ENTERPRISE LIMI...         NaN         NaN
# 3  Membership Discount - Applicable<br />Identifi...         NaN         NaN
# 4  Company Name - NESTLE INDIA LTD<br />Membershi...         NaN         NaN
#
#    Unnamed: 4
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          brand_name
# 0     ORGANIC INDIA
# 1  head & shoulders
# 2          Sunfeast
# 3            Unibic
# 4           CREMICA

# %%
train.manufacturer_description = train['manufacturer_description'].str.lower()

# %%
train["company_name"] = train.manufacturer_description.str.extract(r"company name - ([a-zA-Z-09\. \&]+)")

# %%
train.head()
# Out:
#                                     article_name  \
# 0                    Chicken Burger Patty (250G)
# 1              BRITANNIA DAILY FAMILY LONG BREAD
# 2  POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                            FEVIBOND TUBE 20 ML
# 4             KITKAT DESSERT DELIGHT TRUFFLE 50g
#
#                             manufacturer_description  Unnamed: 2  Unnamed: 3  \
# 0  company name - venkys india ltd<br />membershi...         NaN         NaN
# 1  company name - britannia industries ltd<br />m...         NaN         NaN
# 2  company name - future consumer enterprise limi...         NaN         NaN
# 3  membership discount - applicable<br />identifi...         NaN         NaN
# 4  company name - nestle india ltd<br />membershi...         NaN         NaN
#
#    Unnamed: 4                        company_name
# 0         NaN                    venkys india ltd
# 1         NaN            britannia industries ltd
# 2         NaN  future consumer enterprise limited
# 3         NaN                                 NaN
# 4         NaN                    nestle india ltd

# %%
train['transformed'] = train['article_name'].str.lower()
train['transformed'] = train['transformed'].str.replace("'","")
train['transformed'] = train['transformed'].str.replace("(","")
train['transformed'] = train['transformed'].str.replace(")","")
train['transformed'] = train['transformed'].str.replace(")","")
train['transformed'] = train['transformed'].str.replace("/"," ")
train = train.filter(["article_name", "company_name", "transformed"])

# %%
train.head(10)
# Out:
#                                     article_name  \
# 0                    Chicken Burger Patty (250G)
# 1              BRITANNIA DAILY FAMILY LONG BREAD
# 2  POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                            FEVIBOND TUBE 20 ML
# 4             KITKAT DESSERT DELIGHT TRUFFLE 50g
# 5                 BLUE BIRD SPAGHETTI PASTA 200G
# 6                    NIRAPARA AVALOSE PODI 500GM
# 7               NIVEA ROLL ON FRESH NATURAL 50ml
# 8             FIAMA DW SOAP EXOTIC DREAM BX 115g
# 9       SANGIS KTCN PERI PERI MAYONNAISE BT 200g
#
#                          company_name  \
# 0                    venkys india ltd
# 1            britannia industries ltd
# 2  future consumer enterprise limited
# 3                                 NaN
# 4                    nestle india ltd
# 5       blue bird foods india pvt ltd
# 6                 k k r food products
# 7                                 NaN
# 8                       itc india ltd
# 9                 future consumer ltd
#
#                                      transformed
# 0                      chicken burger patty 250g
# 1              britannia daily family long bread
# 2  pooof potato kettle chips zesty masala pp 30g
# 3                            fevibond tube 20 ml
# 4             kitkat dessert delight truffle 50g
# 5                 blue bird spaghetti pasta 200g
# 6                    nirapara avalose podi 500gm
# 7               nivea roll on fresh natural 50ml
# 8             fiama dw soap exotic dream bx 115g
# 9       sangis ktcn peri peri mayonnaise bt 200g

# %%
train['quantity'] = train['transformed'].str.extract(r'(\d.{0,4}(ml|g|kg|l|s|p))')[0]
#train['quantity'] = train['transformed'].str.extract(r'([0-9].*(ml|g|kg|l|s|p))')

# %%
train.head(50)
# Out:
#                                          article_name  \
# 0                         Chicken Burger Patty (250G)
# 1                   BRITANNIA DAILY FAMILY LONG BREAD
# 2       POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                                 FEVIBOND TUBE 20 ML
# 4                  KITKAT DESSERT DELIGHT TRUFFLE 50g
# 5                      BLUE BIRD SPAGHETTI PASTA 200G
# 6                         NIRAPARA AVALOSE PODI 500GM
# 7                    NIVEA ROLL ON FRESH NATURAL 50ml
# 8                  FIAMA DW SOAP EXOTIC DREAM BX 115g
# 9            SANGIS KTCN PERI PERI MAYONNAISE BT 200g
# 10  Lakme Absolute Youth Infinity Skin Sculpting S...
# 11  Lakme Absolute Perfect Radiance Skin Lightenin...
# 12                  JALARAM KHAKHRA MOBILE JEERA 180g
# 13            SUPER GUMMY C&L IRON & VITAMINS PP 102g
# 14                 CANTINA H&E 6 TORTILLAS XL PP 360g
# 15                      DANISA COOKIES BUTTER TN 200g
# 16                    SAFFOLA MASALA OATS ITALIAN 39G
# 17             COLOUR NAT HRCLR DRKEST BRWN NO3 100ml
# 18           FOODEX SOYA KATORI CHATPATI NAMKEEN 100G
# 19       SUNFEAST FARMLITE OATS & ALMOND BISCUITS 75G
# 20               UNIBIC SUGARFREE OATMEAL COOKIES 75G
# 21                     GLUCON-D ORANGE DRINK MIX 100G
# 22                           GLUCON D NIMBU PANI 450G
# 23             ORGANIC INDIA ORGAIN TULSI TEA BAG 25G
# 24            THINS ORIGINAL FLAVOUR RICE WAFERS 100G
# 25                      ROSTAA MORNING BERRIES PP 35g
# 26             ROSTAA ROASTED SALTED PISTACHIO PP 35g
# 27                     FLYING BIRD KEWRA ESSENCE 20ML
# 28                FLYING BIRD RIPE MANGO ESSENCE 20ML
# 29                     MAGGI NDL CUPPA CHILI CHOW 70g
# 30     PARLE HIDE & SEEK AMERICAN BUTTER COOKIES 200G
# 31                                PATANJALI HONEY 1KG
# 32                           PRIYA GOLD BISCUITS 200G
# 33                                  REVIVE STARCH 50g
# 34             CLMT AIR FRESHENER JASMINE HANG BX 50g
# 14                 cantina h&e 6 tortillas xl pp 360g     360g
# 15                      danisa cookies butter tn 200g     200g
# 16                    saffola masala oats italian 39g      39g
# 17             colour nat hrclr drkest brwn no3 100ml  3 100ml
# 18           foodex soya katori chatpati namkeen 100g     100g
# 19       sunfeast farmlite oats & almond biscuits 75g      75g
# 20               unibic sugarfree oatmeal cookies 75g      75g
# 21                     glucon-d orange drink mix 100g     100g
# 22                           glucon d nimbu pani 450g     450g
# 23             organic india orgain tulsi tea bag 25g      25g
# 24            thins original flavour rice wafers 100g     100g
# 25                      rostaa morning berries pp 35g      35g
# 26             rostaa roasted salted pistachio pp 35g      35g
# 27                     flying bird kewra essence 20ml     20ml
# 28                flying bird ripe mango essence 20ml     20ml
# 29                     maggi ndl cuppa chili chow 70g      70g
# 30     parle hide & seek american butter cookies 200g     200g
# 31                                patanjali honey 1kg      1kg
# 32                           priya gold biscuits 200g     200g
# 33                                  revive starch 50g      50g
# 34             clmt air freshener jasmine hang bx 50g      50g
# 35             clmt plastic disp garbage bag 10p b1g1      10p
# 36                axe deo signature champion bx 122ml    122ml
# 37           yummiez chicken lucknowi shek kabab 400g     400g
# 38               yummiez frozen chicken keema pp 300g     300g
# 39            vaseline bdy ltn int cr hlthy w lgh 40m      NaN
# 40                beeta napkin dinner paper plain 50s      50s
# 41                   appy fizz apple soft drink 250ml    250ml
# 42                        tic tac peach passion 10.7g    10.7g
# 43                               vrka pio botls stbry      NaN
# 44         pepsi soft drink black diet cola can 250ml    250ml
# 45             koka noodles chicken satay flavour 85g      85g
# 46                          gowardhan milk gold pp 1l       1l
# 47              alpenliebe cand juzt jelly mango 185g     185g
# 48           del monte prunes california prem pp 210g     210g
# 49        cadbury bournville raisin nut chocolate 80g      80g

# %%
train_small = train.head(100)
manufacturers['brand_name'] = manufacturers['brand_name'].str.lower()
manufacturers['brand_name'] = manufacturers['brand_name'].str.replace("'","")
manufacturers['brand_name'] = manufacturers['brand_name'].str.replace("(","")
manufacturers['brand_name'] = manufacturers['brand_name'].str.replace(")","")
manufacturers['brand_name'] = manufacturers['brand_name'].str.replace(")","")
manufacturers['brand_name'] = manufacturers['brand_name'].str.replace("/"," ")
manufacturers.head()
# Out:
#          brand_name
# 0     organic india
# 1  head & shoulders
# 2          sunfeast
# 3            unibic
# 4           cremica

# %%
def get_brand_name(article_name, choices):
    maxScore = 0
    maxChoice = ""
    for choice in choices:
        score = fuzz.token_set_ratio(" " + article_name + " ", " " + choice + " ")
        if score > maxScore or (score == maxScore and len(choice) > len(maxChoice)):
            maxScore = score
            maxChoice = choice
    return maxChoice, maxScore

def get_strict(article_name, choices):
    matches = []
    for choice in choices:
        choice1 = choice + " "
        choice2 = " " + choice + " "
        choice3 = " " + choice
        if article_name.startswith(choice1) or article_name.endswith(choice3) or choice2 in article_name:
            matches.append(choice)
    return matches

# %%
train_small["company_name"] = train_small["company_name"].fillna("")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train_small.head()
# Out:
#                                     article_name  \
# 0                    Chicken Burger Patty (250G)
# 1              BRITANNIA DAILY FAMILY LONG BREAD
# 2  POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                            FEVIBOND TUBE 20 ML
# 4             KITKAT DESSERT DELIGHT TRUFFLE 50g
#
#                          company_name  \
# 0                    venkys india ltd
# 1            britannia industries ltd
# 2  future consumer enterprise limited
# 3
# 4                    nestle india ltd
#
#                                      transformed quantity
# 0                      chicken burger patty 250g     250g
# 1              britannia daily family long bread      NaN
# 2  pooof potato kettle chips zesty masala pp 30g      30g
# 3                            fevibond tube 20 ml    20 ml
# 4             kitkat dessert delight truffle 50g      50g

# %%
train_small['strict_transformed'] = train_small['transformed'].apply(lambda x: get_strict(x, manufacturers['brand_name']))
train_small['strict_company'] = train_small['company_name'].apply(lambda x: get_strict(x, manufacturers['brand_name']))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train_small.head()
# Out:
#                                     article_name  \
# 0                    Chicken Burger Patty (250G)
# 1              BRITANNIA DAILY FAMILY LONG BREAD
# 2  POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                            FEVIBOND TUBE 20 ML
# 4             KITKAT DESSERT DELIGHT TRUFFLE 50g
#
#                          company_name  \
# 0                    venkys india ltd
# 1            britannia industries ltd
# 2  future consumer enterprise limited
# 3
# 4                    nestle india ltd
#
#                                      transformed quantity strict_transformed  \
# 0                      chicken burger patty 250g     250g                 []
# 1              britannia daily family long bread      NaN        [britannia]
# 2  pooof potato kettle chips zesty masala pp 30g      30g                 []
# 3                            fevibond tube 20 ml    20 ml         [fevibond]
# 4             kitkat dessert delight truffle 50g      50g                 []
#
#      strict_company
# 0  [venkys, venkys]
# 1       [britannia]
# 2                []
# 3                []
# 4          [nestle]

# %%
train_small['fuzzy_transformed'] = train_small['transformed'].apply(lambda x: get_brand_name(x, manufacturers['brand_name']))
train_small['fuzzy_company'] = train_small['company_name'].apply(lambda x: get_brand_name(x, manufacturers['brand_name']))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train_small.head()
# Out:
#                                     article_name  \
# 0                    Chicken Burger Patty (250G)
# 1              BRITANNIA DAILY FAMILY LONG BREAD
# 2  POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                            FEVIBOND TUBE 20 ML
# 4             KITKAT DESSERT DELIGHT TRUFFLE 50g
#
#                          company_name  \
# 0                    venkys india ltd
# 1            britannia industries ltd
# 2  future consumer enterprise limited
# 3
# 4                    nestle india ltd
#
#                                      transformed quantity strict_transformed  \
# 0                      chicken burger patty 250g     250g                 []
# 1              britannia daily family long bread      NaN        [britannia]
# 2  pooof potato kettle chips zesty masala pp 30g      30g                 []
# 3                            fevibond tube 20 ml    20 ml         [fevibond]
# 4             kitkat dessert delight truffle 50g      50g                 []
#
#      strict_company     fuzzy_transformed                 fuzzy_company
# 0  [venkys, venkys]     (easy choice, 44)                 (venkys, 100)
# 1       [britannia]      (britannia, 100)              (britannia, 100)
# 2                []         (pooof!, 100)            (center fruit, 48)
# 3                []       (fevibond, 100)  (emami fair and handsome, 0)
# 4          [nestle]  (scrub & bright, 35)                 (nestle, 100)

# %%
train_small = train_small.filter(['article_name','company_name','transformed', 'quantity', 'strict_transformed', 'strict_company', 'fuzzy_transformed', 'fuzzy_company']).join(train_small.fuzzy_transformed.apply(lambda loc: pd.Series(loc, index=['fuzzy_brand', 'brand_score']))).join(train_small.fuzzy_company.apply(lambda loc: pd.Series(loc, index=['f_company', 'company_score'])))

# %%
train_small
# Out:
#                                          article_name  \
# 0                         Chicken Burger Patty (250G)
# 1                   BRITANNIA DAILY FAMILY LONG BREAD
# 2       POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                                 FEVIBOND TUBE 20 ML
# 4                  KITKAT DESSERT DELIGHT TRUFFLE 50g
# 5                      BLUE BIRD SPAGHETTI PASTA 200G
# 6                         NIRAPARA AVALOSE PODI 500GM
# 7                    NIVEA ROLL ON FRESH NATURAL 50ml
# 8                  FIAMA DW SOAP EXOTIC DREAM BX 115g
# 9            SANGIS KTCN PERI PERI MAYONNAISE BT 200g
# 10  Lakme Absolute Youth Infinity Skin Sculpting S...
# 11  Lakme Absolute Perfect Radiance Skin Lightenin...
# 12                  JALARAM KHAKHRA MOBILE JEERA 180g
# 13            SUPER GUMMY C&L IRON & VITAMINS PP 102g
# 14                 CANTINA H&E 6 TORTILLAS XL PP 360g
# 15                      DANISA COOKIES BUTTER TN 200g
# 16                    SAFFOLA MASALA OATS ITALIAN 39G
# 17             COLOUR NAT HRCLR DRKEST BRWN NO3 100ml
# 18           FOODEX SOYA KATORI CHATPATI NAMKEEN 100G
# 19       SUNFEAST FARMLITE OATS & ALMOND BISCUITS 75G
# 20               UNIBIC SUGARFREE OATMEAL COOKIES 75G
# 21                     GLUCON-D ORANGE DRINK MIX 100G
# 22                           GLUCON D NIMBU PANI 450G
# 23             ORGANIC INDIA ORGAIN TULSI TEA BAG 25G
# 24            THINS ORIGINAL FLAVOUR RICE WAFERS 100G
# 25                      ROSTAA MORNING BERRIES PP 35g
# 26             ROSTAA ROASTED SALTED PISTACHIO PP 35g
# 27                     FLYING BIRD KEWRA ESSENCE 20ML
# 28                FLYING BIRD RIPE MANGO ESSENCE 20ML
# 29                     MAGGI NDL CUPPA CHILI CHOW 70g
# ..                                                ...
# 70                        GH DAILY URAD DAL PREM 500g
# 71  CADBURY BOURNVITA  LIL CHAMP HEALTH DRINK JAR ...
# 72                     GH WHO SPICE BLACK CARDAMM 20g
# 73                        GH DAILY WHO SPICE RAI 100g
# 74  Sunsilk Nourishing Soft & Smooth Conditioner 8...
# 75              MAYB LIP SMOOTH BALM BERRY CRUSH 4.5g
# 76                            MAGGI SAUCE TOMATO 200g
# 77               BOUNTY CHOCOLATES VALUE PACK PP 171g
# 78             DELICIOUS FROZEN POP CORN BONLESS 250g
# 79              DELICIOUS FROZEN NUGGETS CLASSIC 500g
# 80                   DAAWAT BASMATI RICE PULAV PP 1kg
# 81                  DAWAT BASMATI RICE BIRYANI PP 1kg
# 82              DESI ATTA BHAGAR/SHAMAK/VARAI PP 200g
# 83                        DESI ATTA RAVA DOSA PP 500g
# 84           JOHNSONS SHMP ACTV KIDS SFT&SMTH BT 100m
# 5           [blue bird]       [blue bird]               (blue bird, 100)
# 6            [nirapara]                []                (nirapara, 100)
# 7               [nivea]                []                   (nivea, 100)
# 8                    []                []           (fiama di wills, 53)
# 9                    []                []           (sangis kitchen, 60)
# 10              [lakme]                []                   (lakme, 100)
# 11              [lakme]                []                   (lakme, 100)
# 12                   []                []            (jalaram foods, 70)
# 13        [super gummy]                []             (super gummy, 100)
# 14            [cantina]                []                 (cantina, 100)
# 15             [danisa]                []                  (danisa, 100)
# 16            [saffola]                []                 (saffola, 100)
# 17                   []                []              (godrej no.1, 37)
# 18             [foodex]                []                  (foodex, 100)
# 19           [sunfeast]                []                (sunfeast, 100)
# 20             [unibic]          [unibic]                  (unibic, 100)
# 21           [glucon-d]           [heinz]                (glucon-d, 100)
# 22                   []           [heinz]                (glucon-d, 100)
# 23      [organic india]   [organic india]           (organic india, 100)
# 24              [thins]                []                   (thins, 100)
# 25             [rostaa]           [royal]                  (rostaa, 100)
# 26             [rostaa]           [royal]                  (rostaa, 100)
# 27        [flying bird]          [garden]             (flying bird, 100)
# 28        [flying bird]          [garden]             (flying bird, 100)
# 29              [maggi]          [nestle]                   (maggi, 100)
# ..                  ...               ...                            ...
# 70                   []                []   (golden harvest premium, 37)
# 71            [cadbury]                []                 (cadbury, 100)
# 72                   []                []                (old spice, 71)
# 73                   []                []                (old spice, 71)
# 74            [sunsilk]                []                 (sunsilk, 100)
# 75                   []                []  (beverly hills polo club, 40)
# 76              [maggi]          [nestle]                   (maggi, 100)
# 77             [bounty]            [mars]                  (bounty, 100)
# 78  [delicious, frozen]                []               (delicious, 100)
# 79  [delicious, frozen]                []               (delicious, 100)
# 80             [daawat]                []                  (daawat, 100)
# 81                   []                []  (emami fair and handsome, 39)
# 82                   []                []        (desi atta company, 69)
# 83                   []                []        (desi atta company, 69)
# 84           [johnsons]                []                (johnsons, 100)
# 85                   []                []        (desi atta company, 69)
# 86                   []                []             (namkeen tree, 74)
# 87               [dove]                []                    (dove, 100)
# 88                   []                []            (kwality walls, 70)
# 89                   []                []            (chhagan magan, 38)
# 90           [twinings]                []                (twinings, 100)
# 91           [twinings]                []                (twinings, 100)
# 92           [twinings]        [twinings]                (twinings, 100)
# 93                [lux]                []                     (lux, 100)
# 94             [dilmah]                []                  (dilmah, 100)
# 95           [nilgiris]                []                (nilgiris, 100)
# 96                   []                []               (paper boat, 41)
# 97           [ritebite]                []                (ritebite, 100)
# 98           [nilgiris]                []                (nilgiris, 100)
# 99                 [he]           [emami]                      (he, 100)
#
#                    fuzzy_company              fuzzy_brand  brand_score  \
# 0                  (venkys, 100)              easy choice           44
# 1               (britannia, 100)                britannia          100
# 2             (center fruit, 48)                   pooof!          100
# 3   (emami fair and handsome, 0)                 fevibond          100
# 4                  (nestle, 100)           scrub & bright           35
# 5               (blue bird, 100)                blue bird          100
# 6                 (hr foods, 56)                 nirapara          100
# 7   (emami fair and handsome, 0)                    nivea          100
# 8        (kitchens of india, 67)           fiama di wills           53
# 9             (center fruit, 52)           sangis kitchen           60
# 10             (lever ayush, 48)                    lakme          100
# 11             (lever ayush, 48)                    lakme          100
# 12          (aakash namkeen, 76)            jalaram foods           70
# 13             (healthkart , 49)              super gummy          100
# 14        (haldiram mopleez, 39)                  cantina          100
# 15  (emami fair and handsome, 0)                   danisa          100
# 16              (india gate, 67)                  saffola          100
# 17            (loreal paris, 67)              godrej no.1           37
# 18  (emami fair and handsome, 0)                   foodex          100
# 19       (kitchens of india, 67)                 sunfeast          100
# 20                 (unibic, 100)                   unibic          100
# 21                  (heinz, 100)                 glucon-d          100
# 22                  (heinz, 100)                 glucon-d          100
# 23          (organic india, 100)            organic india          100
# 24              (3m post-it, 45)                    thins          100
# 25                  (royal, 100)                   rostaa          100
# 26                  (royal, 100)                   rostaa          100
# 27                 (garden, 100)              flying bird          100
# 28                 (garden, 100)              flying bird          100
# 29                 (nestle, 100)                    maggi          100
# ..                           ...                      ...          ...
# 70            (center fruit, 51)   golden harvest premium           37
# 71                (hr foods, 77)                  cadbury          100
# 72            (center fruit, 51)                old spice           71
# 73            (center fruit, 51)                old spice           71
# 74             (lever ayush, 48)                  sunsilk          100
# 75            (loreal paris, 67)  beverly hills polo club           40
# 76                 (nestle, 100)                    maggi          100
# 77                   (mars, 100)                   bounty          100
# 78             (kansal agro, 57)                delicious          100
# 79             (kansal agro, 57)                delicious          100
# 80                (hr foods, 77)                   daawat          100
# 81                (hr foods, 77)  emami fair and handsome           39
# 82            (center fruit, 51)        desi atta company           69
# 83            (center fruit, 51)        desi atta company           69
# 84  (emami fair and handsome, 0)                 johnsons          100
# 85            (baker street, 44)        desi atta company           69
# 86                (hr foods, 77)             namkeen tree           74
# 87             (lever ayush, 48)                     dove          100
# 88             (lever ayush, 48)            kwality walls           70
# 89             (lever ayush, 48)            chhagan magan           38
# 90                (hr foods, 77)                 twinings          100
# 91                (hr foods, 77)                 twinings          100
# 92               (twinings, 100)                 twinings          100
# 93             (lever ayush, 48)                      lux          100
# 94                (johnsons, 47)                   dilmah          100
# 95            (mother dairy, 59)                 nilgiris          100
# 96                (hr foods, 77)               paper boat           41
# 97              (india gate, 67)                 ritebite          100
# 98            (mother dairy, 59)                 nilgiris          100
# 99                  (emami, 100)                       he          100
#
#                   f_company  company_score
# 0                    venkys            100
# 1                 britannia            100
# 2              center fruit             48
# 3   emami fair and handsome              0
# 4                    nestle            100
# 5                 blue bird            100
# 6                  hr foods             56
# 7   emami fair and handsome              0
# 8         kitchens of india             67
# 9              center fruit             52
# 10              lever ayush             48
# 11              lever ayush             48
# 12           aakash namkeen             76
# 13              healthkart              49
# 14         haldiram mopleez             39
# 15  emami fair and handsome              0
# 16               india gate             67
# 17             loreal paris             67
# 18  emami fair and handsome              0
# 19        kitchens of india             67
# 20                   unibic            100
# 21                    heinz            100
# 22                    heinz            100
# 23            organic india            100
# 24               3m post-it             45
# 25                    royal            100
# 26                    royal            100
# 27                   garden            100
# 28                   garden            100
# 29                   nestle            100
# ..                      ...            ...
# 70             center fruit             51
# 71                 hr foods             77
# 72             center fruit             51
# 73             center fruit             51
# 74              lever ayush             48
# 75             loreal paris             67
# 76                   nestle            100
# 77                     mars            100
# 78              kansal agro             57
# 79              kansal agro             57
# 80                 hr foods             77
# 81                 hr foods             77
# 82             center fruit             51
# 83             center fruit             51
# 84  emami fair and handsome              0
# 85             baker street             44
# 86                 hr foods             77
# 87              lever ayush             48
# 88              lever ayush             48
# 89              lever ayush             48
# 90                 hr foods             77
# 91                 hr foods             77
# 92                 twinings            100
# 93              lever ayush             48
# 94                 johnsons             47
# 95             mother dairy             59
# 96                 hr foods             77
# 97               india gate             67
# 98             mother dairy             59
# 99                    emami            100
#
# [100 rows x 12 columns]

# %%
del train_small['fuzzy_transformed']
del train_small['fuzzy_company']

# %%
train_small
# Out:
#                                          article_name  \
# 0                         Chicken Burger Patty (250G)
# 1                   BRITANNIA DAILY FAMILY LONG BREAD
# 2       POOOF POTATO KETTLE CHIPS ZESTY MASALA PP 30g
# 3                                 FEVIBOND TUBE 20 ML
# 4                  KITKAT DESSERT DELIGHT TRUFFLE 50g
# 5                      BLUE BIRD SPAGHETTI PASTA 200G
# 6                         NIRAPARA AVALOSE PODI 500GM
# 7                    NIVEA ROLL ON FRESH NATURAL 50ml
# 8                  FIAMA DW SOAP EXOTIC DREAM BX 115g
# 9            SANGIS KTCN PERI PERI MAYONNAISE BT 200g
# 10  Lakme Absolute Youth Infinity Skin Sculpting S...
# 11  Lakme Absolute Perfect Radiance Skin Lightenin...
# 12                  JALARAM KHAKHRA MOBILE JEERA 180g
# 13            SUPER GUMMY C&L IRON & VITAMINS PP 102g
# 14                 CANTINA H&E 6 TORTILLAS XL PP 360g
# 15                      DANISA COOKIES BUTTER TN 200g
# 16                    SAFFOLA MASALA OATS ITALIAN 39G
# 17             COLOUR NAT HRCLR DRKEST BRWN NO3 100ml
# 18           FOODEX SOYA KATORI CHATPATI NAMKEEN 100G
# 19       SUNFEAST FARMLITE OATS & ALMOND BISCUITS 75G
# 20               UNIBIC SUGARFREE OATMEAL COOKIES 75G
# 21                     GLUCON-D ORANGE DRINK MIX 100G
# 22                           GLUCON D NIMBU PANI 450G
# 23             ORGANIC INDIA ORGAIN TULSI TEA BAG 25G
# 24            THINS ORIGINAL FLAVOUR RICE WAFERS 100G
# 25                      ROSTAA MORNING BERRIES PP 35g
# 26             ROSTAA ROASTED SALTED PISTACHIO PP 35g
# 27                     FLYING BIRD KEWRA ESSENCE 20ML
# 28                FLYING BIRD RIPE MANGO ESSENCE 20ML
# 29                     MAGGI NDL CUPPA CHILI CHOW 70g
# ..                                                ...
# 70                        GH DAILY URAD DAL PREM 500g
# 71  CADBURY BOURNVITA  LIL CHAMP HEALTH DRINK JAR ...
# 72                     GH WHO SPICE BLACK CARDAMM 20g
# 73                        GH DAILY WHO SPICE RAI 100g
# 74  Sunsilk Nourishing Soft & Smooth Conditioner 8...
# 75              MAYB LIP SMOOTH BALM BERRY CRUSH 4.5g
# 76                            MAGGI SAUCE TOMATO 200g
# 77               BOUNTY CHOCOLATES VALUE PACK PP 171g
# 98             nilgiris butter cashew biscuit bx 100g     100g
# 99             he deo perfumed passion spray cn 122ml    122ml
#
#      strict_transformed    strict_company              fuzzy_brand  \
# 0                    []  [venkys, venkys]              easy choice
# 1           [britannia]       [britannia]                britannia
# 2                    []                []                   pooof!
# 3            [fevibond]                []                 fevibond
# 4                    []          [nestle]           scrub & bright
# 5           [blue bird]       [blue bird]                blue bird
# 6            [nirapara]                []                 nirapara
# 7               [nivea]                []                    nivea
# 8                    []                []           fiama di wills
# 9                    []                []           sangis kitchen
# 10              [lakme]                []                    lakme
# 11              [lakme]                []                    lakme
# 12                   []                []            jalaram foods
# 13        [super gummy]                []              super gummy
# 14            [cantina]                []                  cantina
# 15             [danisa]                []                   danisa
# 16            [saffola]                []                  saffola
# 17                   []                []              godrej no.1
# 18             [foodex]                []                   foodex
# 19           [sunfeast]                []                 sunfeast
# 20             [unibic]          [unibic]                   unibic
# 21           [glucon-d]           [heinz]                 glucon-d
# 22                   []           [heinz]                 glucon-d
# 23      [organic india]   [organic india]            organic india
# 24              [thins]                []                    thins
# 25             [rostaa]           [royal]                   rostaa
# 26             [rostaa]           [royal]                   rostaa
# 27        [flying bird]          [garden]              flying bird
# 28        [flying bird]          [garden]              flying bird
# 29              [maggi]          [nestle]                    maggi
# ..                  ...               ...                      ...
# 70                   []                []   golden harvest premium
# 71            [cadbury]                []                  cadbury
# 72                   []                []                old spice
# 73                   []                []                old spice
# 74            [sunsilk]                []                  sunsilk
# 75                   []                []  beverly hills polo club
# 76              [maggi]          [nestle]                    maggi
# 77             [bounty]            [mars]                   bounty
# 78  [delicious, frozen]                []                delicious
# 79  [delicious, frozen]                []                delicious
# 80             [daawat]                []                   daawat
# 81                   []                []  emami fair and handsome
# 82                   []                []        desi atta company
# 83                   []                []        desi atta company
# 84           [johnsons]                []                 johnsons
# 85                   []                []        desi atta company
# 86                   []                []             namkeen tree
# 87               [dove]                []                     dove
# 88                   []                []            kwality walls
# 89                   []                []            chhagan magan
# 90           [twinings]                []                 twinings
# 91           [twinings]                []                 twinings
# 92           [twinings]        [twinings]                 twinings
# 93                [lux]                []                      lux
# 94             [dilmah]                []                   dilmah
# 95           [nilgiris]                []                 nilgiris
# 96                   []                []               paper boat
# 97           [ritebite]                []                 ritebite
# 98           [nilgiris]                []                 nilgiris
# 99                 [he]           [emami]                       he
#
#     brand_score                f_company  company_score
# 0            44                   venkys            100
# 1           100                britannia            100
# 2           100             center fruit             48
# 3           100  emami fair and handsome              0
# 4            35                   nestle            100
# 5           100                blue bird            100
# 6           100                 hr foods             56
# 7           100  emami fair and handsome              0
# 8            53        kitchens of india             67
# 9            60             center fruit             52
# 10          100              lever ayush             48
# 11          100              lever ayush             48
# 12           70           aakash namkeen             76
# 13          100              healthkart              49
# 14          100         haldiram mopleez             39
# 15          100  emami fair and handsome              0
# 16          100               india gate             67
# 17           37             loreal paris             67
# 18          100  emami fair and handsome              0
# 19          100        kitchens of india             67
# 20          100                   unibic            100
# 21          100                    heinz            100
# 22          100                    heinz            100
# 23          100            organic india            100
# 24          100               3m post-it             45
# 25          100                    royal            100
# 26          100                    royal            100
# 27          100                   garden            100
# 28          100                   garden            100
# 29          100                   nestle            100
# ..          ...                      ...            ...
# 70           37             center fruit             51
# 71          100                 hr foods             77
# 72           71             center fruit             51
# 73           71             center fruit             51
# 74          100              lever ayush             48
# 75           40             loreal paris             67
# 76          100                   nestle            100
# 77          100                     mars            100
# 78          100              kansal agro             57
# 79          100              kansal agro             57
# 80          100                 hr foods             77
# 81           39                 hr foods             77
# 82           69             center fruit             51
# 83           69             center fruit             51
# 84          100  emami fair and handsome              0
# 85           69             baker street             44
# 86           74                 hr foods             77
# 87          100              lever ayush             48
# 88           70              lever ayush             48
# 89           38              lever ayush             48
# 90          100                 hr foods             77
# 91          100                 hr foods             77
# 92          100                 twinings            100
# 93          100              lever ayush             48
# 94          100                 johnsons             47
# 95          100             mother dairy             59
# 96           41                 hr foods             77
# 97          100               india gate             67
# 98          100             mother dairy             59
# 99          100                    emami            100
#
# [100 rows x 10 columns]

# %%
train_small["final_brand"] = train_small.apply(lambda x: x.fuzzy_brand if x.brand_score > 50 else x.strict_company[0] if len(x.strict_company) > 0 else None, axis=1)

# %%
train_final = train_small.filter(["transformed", "quantity", "final_brand"])

# %%
train_final
# Out:
#                                           transformed quantity  \
# 0                           chicken burger patty 250g     250g
# 1                   britannia daily family long bread      NaN
# 2       pooof potato kettle chips zesty masala pp 30g      30g
# 3                                 fevibond tube 20 ml    20 ml
# 4                  kitkat dessert delight truffle 50g      50g
# 5                      blue bird spaghetti pasta 200g     200g
# 6                         nirapara avalose podi 500gm     500g
# 7                    nivea roll on fresh natural 50ml     50ml
# 8                  fiama dw soap exotic dream bx 115g     115g
# 9            sangis ktcn peri peri mayonnaise bt 200g     200g
# 10  lakme absolute youth infinity skin sculpting s...    30 ml
# 11  lakme absolute perfect radiance skin lightenin...    30 ml
# 12                  jalaram khakhra mobile jeera 180g     180g
# 13            super gummy c&l iron & vitamins pp 102g     102g
# 14                 cantina h&e 6 tortillas xl pp 360g     360g
# 15                      danisa cookies butter tn 200g     200g
# 16                    saffola masala oats italian 39g      39g
# 17             colour nat hrclr drkest brwn no3 100ml  3 100ml
# 18           foodex soya katori chatpati namkeen 100g     100g
# 19       sunfeast farmlite oats & almond biscuits 75g      75g
# 20               unibic sugarfree oatmeal cookies 75g      75g
# 21                     glucon-d orange drink mix 100g     100g
# 22                           glucon d nimbu pani 450g     450g
# 23             organic india orgain tulsi tea bag 25g      25g
# 24            thins original flavour rice wafers 100g     100g
# 25                      rostaa morning berries pp 35g      35g
# 26             rostaa roasted salted pistachio pp 35g      35g
# 27                     flying bird kewra essence 20ml     20ml
# 28                flying bird ripe mango essence 20ml     20ml
# 29                     maggi ndl cuppa chili chow 70g      70g
# ..                                                ...      ...
# 70                        gh daily urad dal prem 500g     500g
# 71  cadbury bournvita  lil champ health drink jar ...     200g
# 72                     gh who spice black cardamm 20g      20g
# 73                        gh daily who spice rai 100g     100g
# 74  sunsilk nourishing soft & smooth conditioner 8...    80 ml
# 75              mayb lip smooth balm berry crush 4.5g     4.5g
# 76                            maggi sauce tomato 200g     200g
# 77               bounty chocolates value pack pp 171g     171g
# 78             delicious frozen pop corn bonless 250g     250g
# 79              delicious frozen nuggets classic 500g     500g
# 80                   daawat basmati rice pulav pp 1kg      1kg
# 81                  dawat basmati rice biryani pp 1kg      1kg
# 82              desi atta bhagar shamak varai pp 200g     200g
# 83                        desi atta rava dosa pp 500g     500g
# 84           johnsons shmp actv kids sft&smth bt 100m      NaN
# 85            desi atta co peri peri idli mix pp 200g     200g
# 86                haldiram namkeen lemon bhel pp 150g     150g
# 87           dove shmp regenerative repair tube 240ml    240ml
# 88           kwality wa ice crm tuti frty 700m 1+1 op   1+1 op
# 89                           kw magnum chotruffle 90m      NaN
# 90      imported twinings cranberry & raspberry 20pcs    20pcs
# 91         imported twinings blackcurrant burst 20pcs    20pcs
# 92           twinings tea bag green tea jasmine 25pcs    25pcs
# 93                  lux sandal & cream soap bar 100 g    100 g
# 94                        dilmah lemon tea bag 25 pcs   25 pcs
# 95           nilgiris cheese spread spicy pepper 180g     180g
# 96                      wafer biscuit pineapple waffy      NaN
# 97               ritebite work out choco classic 50gm      50g
# 98             nilgiris butter cashew biscuit bx 100g     100g
# 99             he deo perfumed passion spray cn 122ml    122ml
#
#           final_brand
# 0              venkys
# 1           britannia
# 2              pooof!
# 3            fevibond
# 4              nestle
# 5           blue bird
# 6            nirapara
# 7               nivea
# 8      fiama di wills
# 9      sangis kitchen
# 10              lakme
# 11              lakme
# 12      jalaram foods
# 13        super gummy
# 14            cantina
# 15             danisa
# 16            saffola
# 17               None
# 18             foodex
# 19           sunfeast
# 20             unibic
# 21           glucon-d
# 22           glucon-d
# 23      organic india
# 24              thins
# 25             rostaa
# 26             rostaa
# 27        flying bird
# 28        flying bird
# 29              maggi
# ..                ...
# 70               None
# 71            cadbury
# 72          old spice
# 73          old spice
# 74            sunsilk
# 75               None
# 76              maggi
# 77             bounty
# 78          delicious
# 79          delicious
# 80             daawat
# 81               None
# 82  desi atta company
# 83  desi atta company
# 84           johnsons
# 85  desi atta company
# 86       namkeen tree
# 87               dove
# 88      kwality walls
# 89               None
# 90           twinings
# 91           twinings
# 92           twinings
# 93                lux
# 94             dilmah
# 95           nilgiris
# 96               None
# 97           ritebite
# 98           nilgiris
# 99                 he
#
# [100 rows x 3 columns]

# %%
import difflib

# %%
def matches(large_string, query_string, threshold):
    words = large_string.split()
    for word in words:
        s = difflib.SequenceMatcher(None, word, query_string)
        match = ''.join(word[i:i+n] for i, j, n in s.get_matching_blocks() if n)
        if len(match) / float(len(query_string)) >= threshold:
            yield match

# def better_matches(large_string, query_string, threshold):
#     large_string_tokens = large_string.strip().split(" ")
#     query_string_tokens = query_string.strip().split(" ")
#     print(large_string_tokens)
#     print(query_string_tokens)
#     for large_token in large_string_tokens:
#         for query_token in query_string_tokens:
#             score = fuzz.token_set_ratio(query_token, large_token)
#             if score > threshold:
#                 large_string_tokens.remove()
#             print(query_token + " " + large_token + " " + str(score))

# %%
large_string = "kwalit wa ice crm tuti frty 700m 1+1 op"
query_string = " kwality walls "
print(list(matches(large_string, query_string, 0.3)))
# print(list(better_matches(large_string, query_string, 70)))
# Out:
# ['kwalit']

# %%
def get_cleaned_article(large, query_string):
    match_list = matches(large, " " + query_string + " ", 0.3)
    for match in match_list:
        large = large.replace(match, "")
    return large.strip()
get_cleaned_article(large_string, query_string)
# Out:
# 'wa ice crm tuti frty 700m 1+1 op'

# %%
train_final["filtered"] = train_final.apply(lambda x: x.transformed if x.final_brand is None else get_cleaned_article(x.transformed, x.final_brand), axis=1)

# %%
train_filtered = train_final.filter(['filtered', 'quantity', 'final_brand'])

# %%
train_filtered
# Out:
#                                              filtered quantity  \
# 0                           chicken burger patty 250g     250g
# 1                             daily family long bread      NaN
# 2             potato kettle chips zesty masala pp 30g      30g
# 3                                          tube 20 ml    20 ml
# 4                  kitkat dessert delight truffle 50g      50g
# 5                                spaghetti pasta 200g     200g
# 6                                  avalose podi 500gm     500g
# 7                          roll on fresh natural 50ml     50ml
# 8                        dw soap exotic dream bx 115g     115g
# 9                   ktcn peri peri mayonnaise bt 200g     200g
# 10  absolute youth infinity skin sculpting serum 3...    30 ml
# 11  absolute perfect radiance skin lightening uv l...    30 ml
# 12                          khakhra mobile jeera 180g     180g
# 13                        c&l iron & vitamins pp 102g     102g
# 14                         h&e 6 tortillas xl pp 360g     360g
# 15                             cookies butter tn 200g     200g
# 16                                ma oats italian 39g      39g
# 17             colour nat hrclr drkest brwn no3 100ml  3 100ml
# 18                  soya katori chatpati namkeen 100g     100g
# 19                farmlite oats & almond biscuits 75g      75g
# 20                      sugarfree oatmeal cookies 75g      75g
# 21                              orange drink mix 100g     100g
# 22                                  d nimbu pani 450g     450g
# 23                                  tulsi tea bag 25g      25g
# 24                  original flavour rice wafers 100g     100g
# 25                             morning berries pp 35g      35g
# 26                       roasted salted pichio pp 35g      35g
# 27                                 kewra essence 20ml     20ml
# 28                            ripe mango essence 20ml     20ml
# 29                           ndl cuppa chili chow 70g      70g
# ..                                                ...      ...
# 70                        gh daily urad dal prem 500g     500g
# 71         bournvita  lil champ health drink jar 200g     200g
# 72                          gh who  black cardamm 20g      20g
# 73                             gh daily who  rai 100g     100g
# 74         nourishing soft & smooth conditioner 80 ml    80 ml
# 75              mayb lip smooth balm berry crush 4.5g     4.5g
# 76                                  sauce tomato 200g     200g
# 77                      chocolates value pack pp 171g     171g
# 78                       frozen pop corn bonless 250g     250g
# 79                        frozen nuggets classic 500g     500g
# 80                          basmati rice pulav pp 1kg      1kg
# 81                  dawat basmati rice biryani pp 1kg      1kg
# 82              desi atta bhagar shamak varai pp 200g     200g
# 83                        desi atta rava dosa pp 500g     500g
# 84                    shmp actv kids sft&smth bt 100m      NaN
# 85            desi atta co peri peri idli mix pp 200g     200g
# 86                       haldiram  lemon bhel pp 150g     150g
# 87                  shmp regenerati repair tube 240ml    240ml
# 88                   wa ice crm tuti frty 700m 1+1 op   1+1 op
# 89                           kw magnum chotruffle 90m      NaN
# 90              imported  cranberry & raspberry 20pcs    20pcs
# 91                 imported  blackcurrant burst 20pcs    20pcs
# 92                    tea bag green tea jasmine 25pcs    25pcs
# 93                      sandal & cream soap bar 100 g    100 g
# 94                               lemon tea bag 25 pcs   25 pcs
# 95                    cheese spread spicy pepper 180g     180g
# 96                      wafer biscuit pineapple waffy      NaN
# 97                        work out choco classic 50gm      50g
# 98                      butter cashew biscuit bx 100g     100g
# 99                deo perfumed passion spray cn 122ml    122ml
#
#           final_brand
# 0              venkys
# 1           britannia
# 2              pooof!
# 3            fevibond
# 4              nestle
# 5           blue bird
# 6            nirapara
# 7               nivea
# 8      fiama di wills
# 9      sangis kitchen
# 10              lakme
# 11              lakme
# 12      jalaram foods
# 13        super gummy
# 14            cantina
# 15             danisa
# 16            saffola
# 17               None
# 18             foodex
# 19           sunfeast
# 20             unibic
# 21           glucon-d
# 22           glucon-d
# 23      organic india
# 24              thins
# 25             rostaa
# 26             rostaa
# 27        flying bird
# 28        flying bird
# 29              maggi
# ..                ...
# 70               None
# 71            cadbury
# 72          old spice
# 73          old spice
# 74            sunsilk
# 75               None
# 76              maggi
# 77             bounty
# 78          delicious
# 79          delicious
# 80             daawat
# 81               None
# 82  desi atta company
# 83  desi atta company
# 84           johnsons
# 85  desi atta company
# 86       namkeen tree
# 87               dove
# 88      kwality walls
# 89               None
# 90           twinings
# 91           twinings
# 92           twinings
# 93                lux
# 94             dilmah
# 95           nilgiris
# 96               None
# 97           ritebite
# 98           nilgiris
# 99                 he
#
# [100 rows x 3 columns]

# %%
train_filtered["quantity"] = train_filtered["quantity"].fillna("")

# %%
train_filtered
# Out:
#                                              filtered quantity  \
# 0                           chicken burger patty 250g     250g
# 1                             daily family long bread
# 2             potato kettle chips zesty masala pp 30g      30g
# 3                                          tube 20 ml    20 ml
# 4                  kitkat dessert delight truffle 50g      50g
# 5                                spaghetti pasta 200g     200g
# 6                                  avalose podi 500gm     500g
# 7                          roll on fresh natural 50ml     50ml
# 8                        dw soap exotic dream bx 115g     115g
# 9                   ktcn peri peri mayonnaise bt 200g     200g
# 10  absolute youth infinity skin sculpting serum 3...    30 ml
# 11  absolute perfect radiance skin lightening uv l...    30 ml
# 12                          khakhra mobile jeera 180g     180g
# 13                        c&l iron & vitamins pp 102g     102g
# 14                         h&e 6 tortillas xl pp 360g     360g
# 15                             cookies butter tn 200g     200g
# 16                                ma oats italian 39g      39g
# 17             colour nat hrclr drkest brwn no3 100ml  3 100ml
# 18                  soya katori chatpati namkeen 100g     100g
# 19                farmlite oats & almond biscuits 75g      75g
# 20                      sugarfree oatmeal cookies 75g      75g
# 21                              orange drink mix 100g     100g
# 22                                  d nimbu pani 450g     450g
# 23                                  tulsi tea bag 25g      25g
# 24                  original flavour rice wafers 100g     100g
# 25                             morning berries pp 35g      35g
# 26                       roasted salted pichio pp 35g      35g
# 27                                 kewra essence 20ml     20ml
# 28                            ripe mango essence 20ml     20ml
# 29                           ndl cuppa chili chow 70g      70g
# ..                                                ...      ...
# 70                        gh daily urad dal prem 500g     500g
# 71         bournvita  lil champ health drink jar 200g     200g
# 72                          gh who  black cardamm 20g      20g
# 73                             gh daily who  rai 100g     100g
# 74         nourishing soft & smooth conditioner 80 ml    80 ml
# 75              mayb lip smooth balm berry crush 4.5g     4.5g
# 76                                  sauce tomato 200g     200g
# 77                      chocolates value pack pp 171g     171g
# 78                       frozen pop corn bonless 250g     250g
# 79                        frozen nuggets classic 500g     500g
# 80                          basmati rice pulav pp 1kg      1kg
# 81                  dawat basmati rice biryani pp 1kg      1kg
# 82              desi atta bhagar shamak varai pp 200g     200g
# 83                        desi atta rava dosa pp 500g     500g
# 84                    shmp actv kids sft&smth bt 100m
# 85            desi atta co peri peri idli mix pp 200g     200g
# 86                       haldiram  lemon bhel pp 150g     150g
# 87                  shmp regenerati repair tube 240ml    240ml
# 88                   wa ice crm tuti frty 700m 1+1 op   1+1 op
# 89                           kw magnum chotruffle 90m
# 90              imported  cranberry & raspberry 20pcs    20pcs
# 91                 imported  blackcurrant burst 20pcs    20pcs
# 92                    tea bag green tea jasmine 25pcs    25pcs
# 93                      sandal & cream soap bar 100 g    100 g
# 94                               lemon tea bag 25 pcs   25 pcs
# 95                    cheese spread spicy pepper 180g     180g
# 96                      wafer biscuit pineapple waffy
# 97                        work out choco classic 50gm      50g
# 98                      butter cashew biscuit bx 100g     100g
# 99                deo perfumed passion spray cn 122ml    122ml
#
#           final_brand
# 0              venkys
# 1           britannia
# 2              pooof!
# 3            fevibond
# 4              nestle
# 5           blue bird
# 6            nirapara
# 7               nivea
# 8      fiama di wills
# 9      sangis kitchen
# 10              lakme
# 11              lakme
# 12      jalaram foods
# 13        super gummy
# 14            cantina
# 15             danisa
# 16            saffola
# 17               None
# 18             foodex
# 19           sunfeast
# 20             unibic
# 21           glucon-d
# 22           glucon-d
# 23      organic india
# 24              thins
# 25             rostaa
# 26             rostaa
# 27        flying bird
# 28        flying bird
# 29              maggi
# ..                ...
# 70               None
# 71            cadbury
# 72          old spice
# 73          old spice
# 74            sunsilk
# 75               None
# 76              maggi
# 77             bounty
# 78          delicious
# 79          delicious
# 80             daawat
# 81               None
# 82  desi atta company
# 83  desi atta company
# 84           johnsons
# 85  desi atta company
# 86       namkeen tree
# 87               dove
# 88      kwality walls
# 89               None
# 90           twinings
# 91           twinings
# 92           twinings
# 93                lux
# 94             dilmah
# 95           nilgiris
# 96               None
# 97           ritebite
# 98           nilgiris
# 99                 he
#
# [100 rows x 3 columns]

# %%
train_filtered["filtered"] = train_filtered.apply(lambda x: get_cleaned_article(x.filtered, str(x.quantity)), axis=1)

# %%
train_filtered
# Out:
#                                              filtered quantity  \
# 0                                chicken burger patty     250g
# 1                             daily family long bread
# 2                 potato kettle chips zesty masala pp      30g
# 3                                          tube 20 ml    20 ml
# 4                      kitkat dessert delight truffle      50g
# 5                                     spaghetti pasta     200g
# 6                                      avalose podi m     500g
# 7                               roll on fresh natural     50ml
# 8                             dw soap exotic dream bx     115g
# 9                        ktcn peri peri mayonnaise bt     200g
# 10  absolute youth infinity skin sculpting serum 3...    30 ml
# 11  absolute perfect radiance skin lightening uv l...    30 ml
# 12                               khakhra mobile jeera     180g
# 13                             c&l iron & vitamins pp     102g
# 14                              h&e 6 tortillas xl pp     360g
# 15                                  cookies butter tn     200g
# 16                                    ma oats italian      39g
# 17                   colour nat hrclr drkest brwn no3  3 100ml
# 18                       soya katori chatpati namkeen     100g
# 19                    farmlite oats & almond biscuits      75g
# 20                          sugarfree oatmeal cookies      75g
# 21                                   orange drink mix     100g
# 22                                       d nimbu pani     450g
# 23                                      tulsi tea bag      25g
# 24                       original flavour rice wafers     100g
# 25                                 morning berries pp      35g
# 26                           roasted salted pichio pp      35g
# 27                                      kewra essence     20ml
# 28                                 ripe mango essence     20ml
# 29                               ndl cuppa chili chow      70g
# ..                                                ...      ...
# 70                             gh daily urad dal prem     500g
# 71              bournvita  lil champ health drink jar     200g
# 72                              gh who  black cardamm      20g
# 73                                  gh daily who  rai     100g
# 74         nourishing soft & smooth conditioner 80 ml    80 ml
# 75                   mayb lip smooth balm berry crush     4.5g
# 76                                       sauce tomato     200g
# 77                           chocolates value pack pp     171g
# 78                            frozen pop corn bonless     250g
# 79                             frozen nuggets classic     500g
# 80                              basmati rice pulav pp      1kg
# 81                      dawat basmati rice biryani pp      1kg
# 82                   desi atta bhagar shamak varai pp     200g
# 83                             desi atta rava dosa pp     500g
# 84                    shmp actv kids sft&smth bt 100m
# 85                 desi atta co peri peri idli mix pp     200g
# 86                            haldiram  lemon bhel pp     150g
# 87                        shmp regenerati repair tube    240ml
# 88                      wa ice crm tuti frty 700m  op   1+1 op
# 89                           kw magnum chotruffle 90m
# 90                    imported  cranberry & raspberry    20pcs
# 91                       imported  blackcurrant burst    20pcs
# 92                          tea bag green tea jasmine    25pcs
# 93                         sandal & cream soap bar  g    100 g
# 94                                   lemon tea bag 25   25 pcs
# 95                         cheese spread spicy pepper     180g
# 96                      wafer biscuit pineapple waffy
# 97                           work out choco classic m      50g
# 98                           butter cashew biscuit bx     100g
# 99                      deo perfumed passion spray cn    122ml
#
#           final_brand
# 0              venkys
# 1           britannia
# 2              pooof!
# 3            fevibond
# 4              nestle
# 5           blue bird
# 6            nirapara
# 7               nivea
# 8      fiama di wills
# 9      sangis kitchen
# 10              lakme
# 11              lakme
# 12      jalaram foods
# 13        super gummy
# 14            cantina
# 15             danisa
# 16            saffola
# 17               None
# 18             foodex
# 19           sunfeast
# 20             unibic
# 21           glucon-d
# 22           glucon-d
# 23      organic india
# 24              thins
# 25             rostaa
# 26             rostaa
# 27        flying bird
# 28        flying bird
# 29              maggi
# ..                ...
# 70               None
# 71            cadbury
# 72          old spice
# 73          old spice
# 74            sunsilk
# 75               None
# 76              maggi
# 77             bounty
# 78          delicious
# 79          delicious
# 80             daawat
# 81               None
# 82  desi atta company
# 83  desi atta company
# 84           johnsons
# 85  desi atta company
# 86       namkeen tree
# 87               dove
# 88      kwality walls
# 89               None
# 90           twinings
# 91           twinings
# 92           twinings
# 93                lux
# 94             dilmah
# 95           nilgiris
# 96               None
# 97           ritebite
# 98           nilgiris
# 99                 he
#
# [100 rows x 3 columns]

# %%
train_filtered.to_csv("filtered.csv", index=False)

# %%
function_filtered = pd.read_csv("filtered_with_fn.csv")

# %%
function_filtered.head()
# Out:
#    Unnamed: 0                             filtered quantity final_brand  \
# 0           0                 chicken burger patty     250g      venkys
# 1           1              daily family long bread      NaN   britannia
# 2           2  potato kettle chips zesty masala pp      30g      pooof!
# 3           3                           tube 20 ml    20 ml    fevibond
# 4           4       kitkat dessert delight truffle      50g      nestle
#
#                                 class1                 class2
# 0                         Ready To Eat           Branded Food
# 1         Biscuits, Cookies & Crackers           Branded Food
# 2             Chips, Namkeens & Snacks           Branded Food
# 3                                  OTC  Beauty &Personal Care
# 4  Chocolates, Cakes & Confectioneries           Branded Food

# %%
def clean_column(column, delimitter_list):
    column = column.str.lower()
    for delimitter in delimitter_list: 
        column = column.str.replace(delimitter," ")
    column = column.str.replace("  "," ")
    column = column.str.replace("  "," ")
    column = column.str.replace("  "," ")
    column = column.str.replace("  "," ")
    column = column.str.replace("  "," ")
    column = column.str.replace("  "," ")
    return column

#clean_column(function_filtered['class1'], ["'", "(", ")", "/", "&", ","])

# %%
function_filtered['class1'] = clean_column(function_filtered['class1'], ["'", "(", ")", "/", "&", ","])

# %%
function_filtered['class2'] = clean_column(function_filtered['class2'], ["'", "(", ")", "/", "&", ","])

# %%
function_filtered['appended_class'] = function_filtered.apply(lambda x: x.class1 + " " + x.class2, axis=1)

# %%
# Out:
#     Unnamed: 0                                           filtered quantity  \
# 0            0                               chicken burger patty     250g
# 1            1                            daily family long bread      NaN
# 2            2                potato kettle chips zesty masala pp      30g
# 3            3                                         tube 20 ml    20 ml
# 4            4                     kitkat dessert delight truffle      50g
# 5            5                                    spaghetti pasta     200g
# 6            6                                     avalose podi m     500g
# 7            7                              roll on fresh natural     50ml
# 8            8                            dw soap exotic dream bx     115g
# 9            9                       ktcn peri peri mayonnaise bt     200g
# 10          10  absolute youth infinity skin sculpting serum 3...    30 ml
# 11          11  absolute perfect radiance skin lightening uv l...    30 ml
# 12          12                               khakhra mobile jeera     180g
# 13          13                             c&l iron & vitamins pp     102g
# 14          14                              h&e 6 tortillas xl pp     360g
# 15          15                                  cookies butter tn     200g
# 16          16                                    ma oats italian      39g
# 17          17                   colour nat hrclr drkest brwn no3  3 100ml
# 18          18                       soya katori chatpati namkeen     100g
# 19          19                    farmlite oats & almond biscuits      75g
# 20          20                          sugarfree oatmeal cookies      75g
# 21          21                                   orange drink mix     100g
# 22          22                                       d nimbu pani     450g
# 23          23                                      tulsi tea bag      25g
# 24          24                       original flavour rice wafers     100g
# 25          25                                 morning berries pp      35g
# 26          26                           roasted salted pichio pp      35g
# 27          27                                      kewra essence     20ml
# 28          28                                 ripe mango essence     20ml
# 29          29                               ndl cuppa chili chow      70g
# ..         ...                                                ...      ...
# 70          70                             gh daily urad dal prem     500g
# 71          71              bournvita  lil champ health drink jar     200g
# 72          72                              gh who  black cardamm      20g
# 73          73                                  gh daily who  rai     100g
# 81                NaN                    organic grains               grocery
# 82  desi atta company                        frozen veg          branded food
# 83  desi atta company                        frozen veg          branded food
# 84           johnsons                              toys       toys stationery
# 85  desi atta company                        frozen veg          branded food
# 86       namkeen tree             chips namkeens snacks          branded food
# 87               dove                         hair care  beauty personal care
# 88      kwality walls                ice cream desserts          branded food
# 89                NaN                              toys       toys stationery
# 90           twinings  chocolates cakes confectioneries          branded food
# 91           twinings                        tea coffee             beverages
# 92           twinings                        tea coffee             beverages
# 93                lux                         skin care  beauty personal care
# 94             dilmah                        tea coffee             beverages
# 95           nilgiris                 sauces puree dips          branded food
# 96                NaN         biscuits cookies crackers          branded food
# 97           ritebite                 breakfast cereals          branded food
# 98           nilgiris  chocolates cakes confectioneries          branded food
# 99                 he                     deos perfumes  beauty personal care
#
#                                    appended_class
# 0                       ready to eat branded food
# 1          biscuits cookies crackers branded food
# 2              chips namkeens snacks branded food
# 3                        otc beauty personal care
# 4   chocolates cakes confectioneries branded food
# 5          noodles pastas vermicelli branded food
# 6                            toys toys stationery
# 7              deos perfumes beauty personal care
# 8                  skin care beauty personal care
# 9                 jams spreads honey branded food
# 10                 skin care beauty personal care
# 11                 skin care beauty personal care
# 12         noodles pastas vermicelli branded food
# 13                     stationery toys stationery
# 14                     stationery toys stationery
# 15  chocolates cakes confectioneries branded food
# 16                 breakfast cereals branded food
# 17                           toys toys stationery
# 18  chocolates cakes confectioneries branded food
# 19         biscuits cookies crackers branded food
# 20         biscuits cookies crackers branded food
# 21                        fun drink mix beverages
# 22                        fun drink mix beverages
# 23                     salt sugar jaggery grocery
# 24                 breakfast cereals branded food
# 25              freshners repellents home hygiene
# 26             chips namkeens snacks branded food
# 27                          masala spices grocery
# 28                          masala spices grocery
# 29         noodles pastas vermicelli branded food
# ..                                            ...
# 70  chocolates cakes confectioneries branded food
# 71                        health drinks beverages
# 72              freshners repellents home hygiene
# 73              freshners repellents home hygiene
# 74                 hair care beauty personal care
# 75                 skin care beauty personal care
# 76                            dals pulses grocery
# 77  chocolates cakes confectioneries branded food
# 78                        frozen veg branded food
# 79                        frozen veg branded food
# 80                         organic grains grocery
# 81                         organic grains grocery
# 82                        frozen veg branded food
# 83                        frozen veg branded food
# 84                           toys toys stationery
# 85                        frozen veg branded food
# 86             chips namkeens snacks branded food
# 87                 hair care beauty personal care
# 88                ice cream desserts branded food
# 89                           toys toys stationery
# 90  chocolates cakes confectioneries branded food
# 91                           tea coffee beverages
# 92                           tea coffee beverages
# 93                 skin care beauty personal care
# 94                           tea coffee beverages
# 95                 sauces puree dips branded food
# 96         biscuits cookies crackers branded food
# 97                 breakfast cereals branded food
# 98  chocolates cakes confectioneries branded food
# 99             deos perfumes beauty personal care
#
# [100 rows x 7 columns]

# %%
def remove_string(large, queries):
    for query in queries.split(" "):
        large = large.replace(query, "")
    large = large.replace("  ", " ")
    large = large.replace("  ", " ")
    return large
remove_string("potato kettle chips zesty masala pp", "chips namkeens snacks branded food")
# Out:
# 'potato kettle zesty masala pp'

# %%
??get_cleaned_article
